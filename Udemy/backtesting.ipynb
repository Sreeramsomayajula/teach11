# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %%
data = yf.download('GRSE.NS',start='2020-01-01',end='2024-11-27')
df = pd.DataFrame(data)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Adj Close        Close         High          Low         Open  \
# Ticker          GRSE.NS      GRSE.NS      GRSE.NS      GRSE.NS      GRSE.NS
# Date
# 2020-01-01   174.756256   198.600006   200.699997   197.800003   199.250000
# 2020-01-02   184.611603   209.800003   212.699997   196.149994   198.000000
# 2020-01-03   180.431885   205.050003   211.000000   203.500000   209.699997
# 2020-01-06   170.180542   193.399994   204.000000   192.050003   204.000000
# 2020-01-07   171.720444   195.149994   199.800003   194.149994   196.699997
# ...                 ...          ...          ...          ...          ...
# 2024-11-19  1409.250000  1409.250000  1456.000000  1401.400024  1422.000000
# 2024-11-21  1381.650024  1381.650024  1424.900024  1377.599976  1422.000000
# 2024-11-22  1375.300049  1375.300049  1398.000000  1371.000000  1391.900024
# ...

# %%
df.head()
df['100sma']=df['Close'].rolling(window=100).mean()
df['50sma']=df['Close'].rolling(window=50).mean()
df['21sma']=df['Close'].rolling(window=21).mean()

# %%
df['signal']=np.where(df['50sma']>df['100sma'],1,0)
df['position']=df['signal'].diff()
df.to_csv('sma.csv')

# %%
df['buyprice']=np.where(df['position']==1,df['Close'],0 )
df['sellprice']=np.where(df['position']==-1, df['Close'], 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'buyprice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
